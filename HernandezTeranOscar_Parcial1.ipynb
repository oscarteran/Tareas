# %% [markdown]
#  # Oscar Hernandez Teran
# ## Geofisica Matemática y Computacional
# ### NoteBook del primer parcial

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f1 = lambda x: ((np.pi*(np.exp(1)-1))/(2))*(np.cos((np.pi*x)/(2)))-np.exp(1)**x

xmin = -2
xmax = 2
x = np.linspace(xmin, xmax, 100)

plt.plot(x,f1(x))
plt.plot([xmin, xmax], [0,0], 'r-', lw=1)
plt.grid()

# %%
f2 = lambda x: np.tan(x)+(1/np.cos(x))**2*(x-1)+np.sin(np.pi*x)+np.pi*x*np.cos(np.pi*x)

xmin = -1
xmax = 1
x = np.linspace(xmin, xmax, 100)

plt.plot(x,f2(x))
plt.plot([xmin, xmax], [0,0], 'r-', lw=1)
plt.grid()

# %%
f3 = lambda x: np.sin(np.pi*x)+np.pi*x*np.cos(np.pi*x)-((x-2)/x)-np.log(x)

xmin = 0.1
xmax = 2
x = np.linspace(xmin, xmax, 100)

plt.plot(x,f3(x))
plt.plot([xmin, xmax], [0,0], 'r-', lw=1)
plt.grid()

# %%
f4 = lambda x: np.cos(np.pi*x)*np.log(x+2)*(x-2)+(((x+2)/(x-2))+np.log(x+2))*np.sin(x)

xmin = -1
xmax = 1
x = np.linspace(xmin, xmax, 100)

plt.plot(x,f4(x))
plt.plot([xmin, xmax], [0,0], 'r-', lw=1)
plt.grid()

# %%
# Ejercicio numero 8

# %%
# Metodo a
n = 21
suma = np.zeros(n)
for i in range(n):
    suma[i] = ((-1)**i*5**i)/np.math.factorial(i)
print("Valor a estimar: ", 0.00673)
print(np.sum(suma))

# Metodo b
n2 = 14
suma2 = np.zeros(n2)
for j in range(n2):
    suma2[j] = (5**j)/(np.math.factorial(j))
res = 1/(np.sum(suma2))
print(res)
# Out:
# Valor a estimar:  0.00673
# 0.006736206992119103
# 0.006739471829362352

# %%
# Ejercicio numero 15
n = 9
suma = np.zeros(n)
for i in range(n):
    suma[i] = ((-1)**i*5**i)/np.math.factorial(i)
print("Valor a estimar: ", 0.00673)
print("Metodo a: ",np.sum(suma))

# Metodo b
suma2 = np.zeros(n)
for j in range(n):
    suma2[j] = (5**j)/(np.math.factorial(j))
res = 1/(np.sum(suma2))
print("Metodo b: ",res)

# Errores
Ea1 = np.fabs(np.exp(-5)-np.sum(suma))
Er1 = (np.fabs(np.exp(-5)-np.sum(suma)))/np.fabs(np.exp(-5))
Ea2 = np.fabs(np.exp(-5)-res)
Er2 = (np.fabs(np.exp(-5)-res)/np.fabs(res))
print("Los errores son: ")
print("Metodo a: ",Ea1," y ",Er1)
print("Metodo b: ",Ea2," y ",Er2)
# Out:
# Valor a estimar:  0.00673
# Metodo a:  3.5551835317460334
# Metodo b:  0.007230283266789744
# Los errores son:
# Metodo a:  3.548445584746948  y  526.6360191358842
# Metodo b:  0.0004923362677042766  y  0.06809363472184882

# %%
#Ejercicio numero 16

# %%
p = np.pi
pa = 22/7
Ea = np.fabs(p-pa)
Er = np.fabs(p-pa)/np.fabs(p)
print(Ea,Er)

p2 = np.exp(10)
pa2 = 22000
Ea = np.fabs(p2-pa2)
Er = np.fabs(p2-pa2)/np.fabs(p2)
print(Ea,Er)

p3 = 10**np.pi
pa3 = 1400
Ea = np.fabs(p3-pa3)
Er = np.fabs(p3-pa3)/np.fabs(p3)
print(Ea,Er)

p4 = np.math.factorial(9)
pa4 = np.sqrt(18*np.pi)*(9/np.exp(1))**9
Ea = np.fabs(p4-pa4)
Er = np.fabs(p4-pa4)/np.fabs(p4)
print(Ea,Er)
# Out:
# 0.0012644892673496777 0.0004024994347707008
# 26.465794806717895 0.0012015452253333286
# 14.544268632989315 0.010497822704619136
# 3343.1271580516477 0.009212762230080598
